# %% [markdown]
# Movie Genre Data Analysis
#
#
# Introduction
#
# We are going to focus highly on genre's. I want to know everything about Genre's.
# Here are some things I want to look at:
#
#
# Research Questions (Q):
#
# Which genres are the most common (number of movies made)?
#
# Which genres have high avg. budget and revenue?
#
# Which genres have high avg. popularity?
#
# Which genres have highest number of movies with an voting avg. >=8?
#
# Research Hypotheses (H):
#
# The best movies according to vote avg. return high profit and revenue.
#
# The best movies according to popularity return high profit and revenue.
#
# Highly budgeted movies return high revenue and profit.
#
# Highly budgeted movies have a high popularity.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\imdb_movies (1).csv")

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df[df.duplicated()]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  ...  \
# 2090  Dwight H. Little  Survival is no game  ...
#
#                                                overview runtime  \
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date vote_count  vote_average  release_year  budget_adj  \
# 2090      3/20/10        110           5.0          2010  30000000.0
#
#       revenue_adj
# 2090     967000.0
#
# [1 rows x 21 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(subset=['genres'],inplace=True)

# %%
df['profit']=df['revenue']-df['budget']

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df_genre = df[['popularity','budget','revenue','original_title','runtime','genres','release_date','vote_count','vote_average','profit']]

# %%
df_genre
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#        runtime                                     genres release_date  \
# ...

# %%
df_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average      profit
# 0           6.5  1363528810
# 1           7.1   228436354
# ...

# %%
from pandas import Series, DataFrame

# %%
split = df_genre['genres'].str.split('|').apply(pd.Series, 1).stack()
split.index = split.index.droplevel(-1)
split.name = 'genres_split'
del df_genre['genres']
df_genre = df_genre.join(split)

# %%
df_genre
# Out:
#        popularity     budget     revenue            original_title  runtime  \
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 1       28.419936  150000000   378436354        Mad Max: Fury Road      120
# ...           ...        ...         ...                       ...      ...
# 10863    0.065141          0           0       Beregis Avtomobilya       94
# 10863    0.065141          0           0       Beregis Avtomobilya       94
# 10864    0.064317          0           0    What's Up, Tiger Lily?       80
# 10864    0.064317          0           0    What's Up, Tiger Lily?       80
# 10865    0.035919      19000           0  Manos: The Hands of Fate       74
#
# ...

# %% [markdown]
# ## Research Questions (Q):
#
#
# ## 1.Which genres are the most common (number of movies made)?

# %%
genres_count = pd. DataFrame(df_genre.groupby ('genres_split').original_title.nunique()).sort_values('original_title')

# %%
genres_count['original_title'].plot.pie(title='Movies Per Genre in %',autopct='%1.1f%%',figsize = (10,10))
# Out:
# <AxesSubplot:title={'center':'Movies Per Genre in %'}, ylabel='original_title'>

# %%
genres_count['original_title'].plot.barh(title='Movies Per Genre')
# Out:
# <AxesSubplot:title={'center':'Movies Per Genre'}, ylabel='genres_split'>

# %% [markdown]
# # 2.Which genres have high avg. budget and revenue?

# %%
genres_avg = df_genre.groupby ('genres_split').mean()
pd.options.display.float_format = '{:2f}'.format
genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# Action             0.926274 27727820.331376  72794732.002517 104.917785
# Adventure          1.154259 37543694.530931 113137861.069341 106.173351
# Animation          0.852182 23159781.606581  75256062.223176  68.181688
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# Family             0.786668 23359337.420796  72433176.373680  89.603574
# Fantasy            0.992840 32612585.348253  96313657.081878 100.736900
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# History            0.575936 18594919.302395  32011793.215569 136.206587
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# ...

# %%
genres_avg.sort_values('budget',ascending=True,inplace=True)

# %%
genres_avg[['budget','revenue']].plot.barh(title='Budget and Revenue by Genre')
# Out:
# <AxesSubplot:title={'center':'Budget and Revenue by Genre'}, ylabel='genres_split'>

# %% [markdown]
# ## 3. Which genres have high avg. profit?

# %%
genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# TV Movie           0.270896   267664.670659    251497.005988  91.982036
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# Music              0.487321  9438627.549020  28571768.691176 105.137255
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# Romance            0.592082 12531271.847547  35691972.327103 106.891355
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Mystery            0.690012 16119270.062963  40217566.661728 105.928395
# Thriller           0.741563 17207693.769178  41728417.543860 103.247678
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# History            0.575936 18594919.302395  32011793.215569 136.206587
# ...

# %%
genres_avg.sort_values('profit',ascending=True,inplace=True)

# %%
genres_avg[['profit']].plot.barh(title='Profit by Genre')
# Out:
# <AxesSubplot:title={'center':'Profit by Genre'}, ylabel='genres_split'>

# %% [markdown]
# ## 4.Which genres have high avg. popularity?

# %%
genres_avg.sort_values('popularity',ascending=True,inplace=True)

# %%
genres_avg[['popularity']].plot.barh(title='Popularity by Genre')
# Out:
# <AxesSubplot:title={'center':'Popularity by Genre'}, ylabel='genres_split'>

# %% [markdown]
# ## 5.Which genres have highest number of movies with an voting avg. >=8?

# %%
df_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#   release_date  vote_count  vote_average      profit  \
# 0       6/9/15        5562      6.500000  1363528810
# 1      5/13/15        6185      7.100000   228436354
# 2      3/18/15        2480      6.300000   185238201
# 3     12/15/15        5292      7.500000  1868178225
# 4       4/1/15        2947      7.300000  1316249360
#
#                                 genres_split
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# ...

# %%
vote_fifty = df_genre[(df_genre['vote_count']>=50) & (df_genre['vote_average']>=8)]

# %%
vote_zero = df_genre[  df_genre['vote_average']>=8]
vote_zero
# Out:
#        popularity     budget    revenue  \
# 9        6.326804  175000000  853708609
# 35       3.557846    6000000   35401758
# 377      0.198522          0          0
# 441      0.220751          0          0
# 536      0.122543          0          0
# ...           ...        ...        ...
# 9979     2.659926   25000000   46836394
# 10141    2.610362     806948   32000000
# 10222    2.377288   22000000  321265768
# 10575    0.195770          0          0
# 10817    0.064029          0     321952
#
#                                     original_title  runtime release_date  \
# 9                                       Inside Out       94       6/9/15
# 35                                            Room      117     10/16/15
# 377                               Hitting the Apex      138       9/2/15
# 441    Winter on Fire: Ukraine's Fight for Freedom       98      10/9/15
# 536                                 A Faster Horse       90      10/8/15
# ...

# %%
genres_vote = pd. DataFrame(vote_fifty.groupby ('genres_split').vote_average.nunique()).sort_values('vote_average',ascending=True)

# %%
genres_vote
# Out:
#                                        vote_average
# genres_split
# Action|Drama|War                                  1
# Romance|Comedy|Animation|Drama|Family             1
# Mystery|Documentary|Crime                         1
# History|Drama|Thriller|War                        1
# Fantasy|Drama|Crime                               1
# Family|Animation|Fantasy                          1
# Drama|Thriller                                    1
# Drama|Music                                       1
# Drama|Horror|Thriller                             1
# Drama|History|War                                 1
# Drama|Crime|Thriller                              1
# Science Fiction|Adventure                         1
# Drama|Action|Crime|Thriller                       1
# Documentary|Music                                 1
# Documentary|Drama                                 1
# Crime|Documentary                                 1
# Comedy|Drama|Romance                              1
# ...

# %%
genres_vote[['vote_average']].plot.barh(title='Vote Average  by Genre')
# Out:
# <AxesSubplot:title={'center':'Vote Average  by Genre'}, ylabel='genres_split'>

# %% [markdown]
# Research Hypotheses (H):
#
# The best movies according to vote avg. return high profit and revenue.
#
# The best movies according to popularity return high profit and revenue.
#
# Highly budgeted movies return high revenue and profit.
#
# Highly budgeted movies have a high popularity.

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\imdb_movies (1).csv")

# %%
df.drop_duplicates(inplace=True)

# %%
df['profit']=df['revenue']-df['budget']
df_genre = df[['popularity','budget','revenue','original_title','runtime','genres','release_date','vote_count','vote_average','profit']]

# %%
df_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average      profit
# 0      6.500000  1363528810
# 1      7.100000   228436354
# ...

# %% [markdown]
# ## 1.The best movies according to vote avg. return high profit and revenue.

# %%
movies_counted = df_genre[df_genre['vote_count'] >= 50]
movies_counted.corr(method='spearman')
# Out:
#               popularity    budget  revenue  runtime  vote_count  \
# popularity      1.000000  0.485149 0.588739 0.230518    0.768966
# budget          0.485149  1.000000 0.714828 0.360230    0.554586
# revenue         0.588739  0.714828 1.000000 0.341707    0.682656
# runtime         0.230518  0.360230 0.341707 1.000000    0.263460
# vote_count      0.768966  0.554586 0.682656 0.263460    1.000000
# vote_average    0.188670 -0.044440 0.111731 0.285514    0.284470
# profit          0.498117  0.334390 0.842221 0.212060    0.583602
#
#               vote_average   profit
# popularity        0.188670 0.498117
# budget           -0.044440 0.334390
# revenue           0.111731 0.842221
# runtime           0.285514 0.212060
# vote_count        0.284470 0.583602
# vote_average      1.000000 0.198308
# profit            0.198308 1.000000

# %%
sns.regplot(x='vote_average',y='profit', data=movies_counted,line_kws={"color":"Blue"})
# Out:
# <AxesSubplot:xlabel='vote_average', ylabel='profit'>

# %%
sns.regplot(x='vote_average',y='revenue', data=movies_counted,line_kws={"color":"Blue"})
# Out:
# <AxesSubplot:xlabel='vote_average', ylabel='revenue'>

# %% [markdown]
# ## 2.The best movies according to popularity return high profit and revenue

# %%
movies_counted.corr(method='spearman')
# Out:
#               popularity    budget  revenue  runtime  vote_count  \
# popularity      1.000000  0.485149 0.588739 0.230518    0.768966
# budget          0.485149  1.000000 0.714828 0.360230    0.554586
# revenue         0.588739  0.714828 1.000000 0.341707    0.682656
# runtime         0.230518  0.360230 0.341707 1.000000    0.263460
# vote_count      0.768966  0.554586 0.682656 0.263460    1.000000
# vote_average    0.188670 -0.044440 0.111731 0.285514    0.284470
# profit          0.498117  0.334390 0.842221 0.212060    0.583602
#
#               vote_average   profit
# popularity        0.188670 0.498117
# budget           -0.044440 0.334390
# revenue           0.111731 0.842221
# runtime           0.285514 0.212060
# vote_count        0.284470 0.583602
# vote_average      1.000000 0.198308
# profit            0.198308 1.000000

# %%
sns.regplot(x='popularity',y='revenue', data=movies_counted,line_kws={"color":"Blue"})
# Out:
# <AxesSubplot:xlabel='popularity', ylabel='revenue'>

# %%
sns.regplot(x='popularity',y='profit', data=movies_counted,line_kws={"color":"Blue"})
# Out:
# <AxesSubplot:xlabel='popularity', ylabel='profit'>

# %% [markdown]
# ## 3.Highly budgeted movies return high profit.

# %%
movies_counted.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average      profit
# 0      6.500000  1363528810
# 1      7.100000   228436354
# ...

# %%
sns.regplot(x='budget',y='profit', data=movies_counted,line_kws={"color":"Blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='profit'>

# %% [markdown]
# ## 4.Take a look at Profit Per Genres per Year

# %%
df_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#   release_date  vote_count  vote_average      profit     genres_split
# 0       6/9/15        5562      6.500000  1363528810           Action
# 0       6/9/15        5562      6.500000  1363528810        Adventure
# 0       6/9/15        5562      6.500000  1363528810  Science Fiction
# 0       6/9/15        5562      6.500000  1363528810         Thriller
# 1      5/13/15        6185      7.100000   228436354           Action

# %%
df_genre2 = df[['popularity','budget','revenue','original_title','runtime','genres','release_year','vote_count','vote_average','profit']]

# %%
df_genre2
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#        runtime                                     genres  release_year  \
# ...

# %%
from pandas import Series, DataFrame

# Split the genres column
split = df_genre2['genres'].str.split('|').apply(Series, 1).stack()
split.index = split.index.droplevel(-1)
split.name = 'genres_split'

# Remove the original genres column
del df_genre2['genres']

# Join the split genres back to df_genre2
df_genre3 = df_genre2.join(split)

# %%
df_genre3
# Out:
#        popularity     budget     revenue            original_title  runtime  \
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 1       28.419936  150000000   378436354        Mad Max: Fury Road      120
# ...           ...        ...         ...                       ...      ...
# 10863    0.065141          0           0       Beregis Avtomobilya       94
# 10863    0.065141          0           0       Beregis Avtomobilya       94
# 10864    0.064317          0           0    What's Up, Tiger Lily?       80
# 10864    0.064317          0           0    What's Up, Tiger Lily?       80
# 10865    0.035919      19000           0  Manos: The Hands of Fate       74
#
# ...

# %%
time_genre = pd.DataFrame(df_genre3.groupby(['release_year','genres_split'])['profit'].mean())

# %%
time_genre
# Out:
#                                       profit
# release_year genres_split
# 1960         Action           6363125.000000
#              Adventure         431000.000000
#              Comedy           5258750.000000
#              Crime                  0.000000
#              Drama            8245619.384615
# ...                                      ...
# 2015         Science Fiction 83321303.523256
#              TV Movie         -150000.000000
#              Thriller        32869106.847953
#              War             54677314.333333
#              Western         72856619.000000
#
# [1049 rows x 1 columns]

# %%
final_genre = pd.pivot_table(time_genre,values='profit',index=['genres_split'],columns=['release_year'])

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(final_genre,cmap='YlGnBu',linewidths= .5)
plt.title('Genres by Profit per Year')
# Out:
# Text(0.5, 1.0, 'Genres by Profit per Year')
